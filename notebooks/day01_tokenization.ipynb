# %%
from transformers import AutoTokenizer

bert_tokenizer = AutoTokenizer.from_pretrained(
    "bert-base-uncased"
)

roberta_tokenizer = AutoTokenizer.from_pretrained(
    "roberta-base"
)
# Out:
# Warning: You are sending unauthenticated requests to the HF Hub. Please set a HF_TOKEN to enable higher rate limits and faster downloads.

# %%
sentence = "Built MLflow pipeline for experiment tracking."

bert = bert_tokenizer.tokenize(sentence)
roberta = roberta_tokenizer.tokenize(sentence)

print(bert)
print(roberta)
# Out:
# ['built', 'ml', '##flow', 'pipeline', 'for', 'experiment', 'tracking', '.']
# ['Built', 'ĠML', 'flow', 'Ġpipeline', 'Ġfor', 'Ġexperiment', 'Ġtracking', '.']

# %%
skills = [
    "MLflow",
    "PyTorch",
    "FastAPI",
    "MLOps",
    "Docker",
    "Kubernetes"
]

for skill in skills:
    print(skill)

    print(
        bert_tokenizer.tokenize(skill)
    )

    print(
        roberta_tokenizer.tokenize(skill)
    )
# Out:
# MLflow
# ['ml', '##flow']
# ['ML', 'flow']
# PyTorch
# ['p', '##yt', '##or', '##ch']
# ['Py', 'Tor', 'ch']
# FastAPI
# ['fast', '##ap', '##i']
# ['Fast', 'API']
# MLOps
# ['ml', '##ops']
# ['ML', 'Ops']
# Docker
# ['dock', '##er']
# ['D', 'ocker']
# Kubernetes
# ['ku', '##ber', '##net', '##es']
# ['K', 'uber', 'net', 'es']
